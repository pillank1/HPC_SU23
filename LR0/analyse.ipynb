# %%
import matplotlib.pyplot as plt

# %%
# Полученные результаты
sz_arr = [100, 200, 400, 800, 1000, 1500, 2000]
cpu_arr = [0.6803257465362549, 0.6558361530303956, 0.7678906917572021, 1.0055694103240966, 1.2960428714752197, 2.4221973419189453, 4.536667013168335]
gpu_arr = [0.00911121368408203, 0.018604612350463866, 0.046222877502441403, 0.18831634521484375, 0.3215197563171387, 1.126345682144165, 2.7303486824035645]
simple_arr = [0.0112030029296875, 0.04521598815917969, 0.23778896331787108, 1.1910597324371337, 2.170572376251221, 6.790839004516601, 15.548768234252929]

# %%
from cProfile import label


plt.figure(figsize=(16, 8))
plt.plot(sz_arr, simple_arr, lw=4, label='Single CPU')
plt.plot(sz_arr, cpu_arr, lw=4, label='MultiCPU')
plt.plot(sz_arr, gpu_arr, lw=4, label='GPU')
plt.grid()
plt.legend()
plt.xlim([sz_arr[0], sz_arr[-1]])
plt.xlabel('Размерность матриц')
plt.ylabel('Скорость выполнения, сек')
plt.show()
